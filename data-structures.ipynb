# %% [markdown]
# ### Python data types

# %% [markdown]
# ### Integer

# %% [markdown]
# Python Integer is a non-fractional number which is unbound, meaning there is no limit to their size. Actually it has a limit since your computer does not have unlimited memory.

# %% [markdown]
# ##### Converting from and to integer

# %%
int('100')
# Out:
# 100

# %%
str(200)
# Out:
# '200'

# %%
int(10.323)
# Out:
# 10

# %% [markdown]
# ##### Python random integer

# %%
import random
random.randint(1, 10)
# Out:
# 10

# %% [markdown]
# ##### check if Python integer

# %%
type(2)
# Out:
# int

# %%
if type(2) == int:
    print('An integer')
# Out:
# An integer

# %%
if isinstance(2, int):
    print('An integer')
# Out:
# An integer

# %% [markdown]
# Don't use if type(2) == int
# Using isinstance() is almost always the better, cleaner way and covers more use cases

# %% [markdown]
# ### Float

# %% [markdown]
# A Python float is a numberical data type that represents a floating-point number.A floating-pointer number is a number with a decimal point or exponent notation, indicating that a number is a certain number of digits before and after the decimal point or exponent.

# %% [markdown]
# ##### Creating floating pointer number

# %%
f = 1.46
f = 1.45e3

# %% [markdown]
# ##### Round, floor and ceil

# %%
f = 1.4567
print(round(f))
print(round(f, 2))
# Out:
# 1
# 1.46

# %%
from math import floor, ceil

x = floor(1.23)
y = ceil(1.67)

print(x, y)
# Out:
# 1 2

# %% [markdown]
# ##### The python float has limited precision

# %%
print(0.3 + 0.1)
print(0.1 + 3.8)
print(0.1 + 0.2)
print(round(0.1 + 0.2, 2))
# Out:
# 0.4
# 3.9
# 0.30000000000000004
# 0.3

# %% [markdown]
# ##### Converting floats to str, int

# %%
my_int = int(1.23)
my_str = str(1.23)

print(my_int, my_str, float(1), float('1.34'))
# Out:
# 1 1.23 1.0 1.34

# %% [markdown]
# ### Tuple

# %% [markdown]
# A Python tuple is one of Python's three built-in sequence data types, the others being lists and range objects.A Python tuple shares a lot of properties with the more commonly known python list

# %% [markdown]
# ##### Createing a Python tuple

# %%
my_numbers = (1, 2, 4, 5)
the_same = 1, 2, 4, 5
my_strings = ('Hello', 'World')
my_mixed_tuple = 'Hello', 123, True

print(my_numbers, the_same, my_strings, my_mixed_tuple)

print(tuple({11, 12, 16}), tuple([11, 12, 16]))
# Out:
# (1, 2, 4, 5) (1, 2, 4, 5) ('Hello', 'World') ('Hello', 123, True)
# (16, 11, 12) (11, 12, 16)

# %% [markdown]
# ##### * operation and multiple assignment

# %%
l1 = [1, 2, 3]
l2 = [4, 5, 6]
t = *l1, *l2

print(t)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# The leading * operator unpacks the lists into individual elements. It’s as if you would have typed them individually at that spot. This unpacking trick works for all iterable types if you were wondering!

# %%
person = ('Erik', 38, True)
name, age, registered = person

print(name, age, registered)
# Out:
# Erik 38 True

# %%
def get_user_by_id(userId):
    name = 'addy'
    age = 2
    return name, age

name, age = get_user_by_id(1)
print('values returned by get_user_by_id function', name, age)
# Out:
# values returned by get_user_by_id function addy 2

# %% [markdown]
# ##### Python Tuple VS List

# %% [markdown]
# - Tuple is immutable but list is mutable.
# - Tuple has better on performance than list, because tuple uses a simple array-like structure in implimentation, however list is implimented as a linked list with operation like inserting elements at random position.

# %% [markdown]
# ##### Python Tuple Vs Set
#
# - Tuple can hold duplicates while a set can't.
#
#   The entire purpose of a set is its inability of containing duplicates. it's an excellent tool for deduplicating your data.

# %% [markdown]
# ##### Converting Tuple to Set and List

# %%
t = 1, 2, 3, 4
print('convert a tuple to list type using list function', list(t))
print('convert a tuple to list type using * operation', [*t])
# Out:
# convert a tuple to list type using list function [1, 2, 3, 4]
# convert a tuple to list type using * operation [1, 2, 3, 4]

# %%
t = 2, 4, 6, 8
print('convert a tuple to set type using set constructor', set(t))
print('convert a tuple to set type using * operation', {*t})
# Out:
# convert a tuple to set type using set constructor {8, 2, 4, 6}
# convert a tuple to set type using * operation {8, 2, 4, 6}

# %% [markdown]
# ##### Length and Indexed access

# %%
t = 1, 2, 4, 6
print(len(t), t[2], t[0])
# Out:
# 4 4 1
