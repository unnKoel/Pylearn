# %% [markdown]
# ### Python data types

# %% [markdown]
# ### Integer

# %% [markdown]
# Python Integer is a non-fractional number which is unbound, meaning there is no limit to their size. Actually it has a limit since your computer does not have unlimited memory.

# %% [markdown]
# ##### Converting from and to integer

# %%
int('100')
# Out:
# 100

# %%
str(200)
# Out:
# '200'

# %%
int(10.323)
# Out:
# 10

# %% [markdown]
# ##### Python random integer

# %%
import random
random.randint(1, 10)
# Out:
# 10

# %% [markdown]
# ##### check if Python integer

# %%
type(2)
# Out:
# int

# %%
if type(2) == int:
    print('An integer')
# Out:
# An integer

# %%
if isinstance(2, int):
    print('An integer')
# Out:
# An integer

# %% [markdown]
# Don't use if type(2) == int
# Using isinstance() is almost always the better, cleaner way and covers more use cases

# %% [markdown]
# ### Float

# %% [markdown]
# A Python float is a numberical data type that represents a floating-point number.A floating-pointer number is a number with a decimal point or exponent notation, indicating that a number is a certain number of digits before and after the decimal point or exponent.

# %% [markdown]
# ##### Creating floating pointer number

# %%
f = 1.46
f = 1.45e3

# %% [markdown]
# ##### Round, floor and ceil

# %%
f = 1.4567
print(round(f))
print(round(f, 2))
# Out:
# 1
# 1.46

# %%
from math import floor, ceil

x = floor(1.23)
y = ceil(1.67)

print(x, y)
# Out:
# 1 2

# %% [markdown]
# ##### The python float has limited precision

# %%
print(0.3 + 0.1)
print(0.1 + 3.8)
print(0.1 + 0.2)
print(round(0.1 + 0.2, 2))
# Out:
# 0.4
# 3.9
# 0.30000000000000004
# 0.3

# %% [markdown]
# ##### Converting floats to str, int

# %%
my_int = int(1.23)
my_str = str(1.23)

print(my_int, my_str, float(1), float('1.34'))
# Out:
# 1 1.23 1.0 1.34

# %% [markdown]
# ### Tuple

# %% [markdown]
# A Python tuple is one of Python's three built-in sequence data types, the others being lists and range objects.A Python tuple shares a lot of properties with the more commonly known python list

# %% [markdown]
# ##### Createing a Python tuple

# %%
my_numbers = (1, 2, 4, 5)
the_same = 1, 2, 4, 5
my_strings = ('Hello', 'World')
my_mixed_tuple = 'Hello', 123, True

print(my_numbers, the_same, my_strings, my_mixed_tuple)

print(tuple({11, 12, 16}), tuple([11, 12, 16]))
# Out:
# (1, 2, 4, 5) (1, 2, 4, 5) ('Hello', 'World') ('Hello', 123, True)
# (16, 11, 12) (11, 12, 16)

# %% [markdown]
# ##### * operation and multiple assignment

# %%
l1 = [1, 2, 3]
l2 = [4, 5, 6]
t = *l1, *l2

print(t)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# The leading * operator unpacks the lists into individual elements. It’s as if you would have typed them individually at that spot. This unpacking trick works for all iterable types if you were wondering!

# %%
person = ('Erik', 38, True)
name, age, registered = person

print(name, age, registered)
# Out:
# Erik 38 True

# %%
def get_user_by_id(userId):
    name = 'addy'
    age = 2
    return name, age

name, age = get_user_by_id(1)
print('values returned by get_user_by_id function', name, age)
# Out:
# values returned by get_user_by_id function addy 2

# %% [markdown]
# ##### Python Tuple VS List

# %% [markdown]
# - Tuple is immutable but list is mutable.
# - Tuple has better on performance than list, because tuple uses a simple array-like structure in implimentation, however list is implimented as a linked list with operation like inserting elements at random position.

# %% [markdown]
# ##### Python Tuple Vs Set
#
# - Tuple can hold duplicates while a set can't.
#
#   The entire purpose of a set is its inability of containing duplicates. it's an excellent tool for deduplicating your data.

# %% [markdown]
# ##### Converting Tuple to Set and List

# %%
t = 1, 2, 3, 4
print('convert a tuple to list type using list function', list(t))
print('convert a tuple to list type using * operation', [*t])
# Out:
# convert a tuple to list type using list function [1, 2, 3, 4]
# convert a tuple to list type using * operation [1, 2, 3, 4]

# %%
t = 2, 4, 6, 8
print('convert a tuple to set type using set constructor', set(t))
print('convert a tuple to set type using * operation', {*t})
# Out:
# convert a tuple to set type using set constructor {8, 2, 4, 6}
# convert a tuple to set type using * operation {8, 2, 4, 6}

# %% [markdown]
# ##### Length and Indexed access

# %%
t = 1, 2, 4, 6
print(len(t), t[2], t[0])
# Out:
# 4 4 1

# %% [markdown]
# ### List

# %% [markdown]
# The Python list is one of the most used data structures together with dictionaries.

# %% [markdown]
# ##### create a Python list

# %%
my_list = [1, 2, 3]
my_list2 = [1, "Erik", { 'age': 39 }]

print(my_list, my_list2)
# Out:
# [1, 2, 3] [1, 'Erik', {'age': 39}]

# %%
my_list = list(range(1, 4))
my_list2 = list({1, 3, 5})
my_list3 = list((1, 2, 3))

print(range(1, 4))
print(my_list, my_list2, my_list3)
# Out:
# range(1, 4)
# [1, 2, 3] [1, 3, 5] [1, 2, 3]

# %% [markdown]
# ##### access list

# %%
my_list = [1, 2, [3, 5]]

print(my_list[1], my_list[2][1], my_list[-2])
# Out:
# 2 5 2

# %% [markdown]
# ##### adding and removing elements

# %%
my_list = [1, 2]
my_list.append('a')
print(my_list)

l1 = [1, 2]
l3 = l1 + my_list
print(l3)

l2 = [7, 7]
l3.extend(l2)
print(l3)

l3.pop()
print(l3)

l3.remove(2)
print(l3)

del(l3[2])
print(l3)

deduplicated = list(set(l3))
print(deduplicated)

deduplicated[0] = 100
print(deduplicated)

deduplicated.clear()
print(deduplicated)
# Out:
# [1, 2, 'a']
# [1, 2, 1, 2, 'a']
# [1, 2, 1, 2, 'a', 7, 7]
# [1, 2, 1, 2, 'a', 7]
# [1, 1, 2, 'a', 7]
# [1, 1, 'a', 7]
# [1, 'a', 7]
# [100, 'a', 7]
# []

# %% [markdown]
# ##### Check if an item is in a list

# %%
my_list = [1,2]
if 1 in my_list:
    print('it\'s in the list')
# Out:
# it's in the list

# %% [markdown]
# ##### Loop over list elements

# %%
my_list = [1, 2, 3, 4, 5]
for n in my_list:
    print(n)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ##### Slicing
#
# The slicing syntax is as follows:
# ```py
# my_list[start:stop:step]
# ```

# %%
my_list = [1, 2, 3, 4, 5, 6, 7, 8]
print(my_list[0:3], my_list[:3], my_list[4:])

my_list2 = [1, 2, 3, 4, 5, 6]
print(my_list2[-1:-3:-1])
# Out:
# [1, 2, 3] [1, 2, 3] [5, 6, 7, 8]
# [6, 5]

# %% [markdown]
# ##### sort and reserve
#
# - list.reverse() & reversed() & [::-1]
# - list.sort() && sorted()

# %% [markdown]
# ### Set
#
# Python sets are unordered collections of distinct objects.

# %% [markdown]
# ##### how to create a python set

# %%
name = { "Eric", "Ali", "John" }

mixed_set = { 'a', 1, (1,2) }

print(name, mixed_set)

my_set = set()
my_set.add(1)
my_set.add('Erik')
my_set.update(range(3))
my_set.update(['a', 'b'])
print(my_set)
print(set([1, 2, 3]))
print(set(range(3)))

my_set_comprehension = { x for x in 'Hi, my name is...' if x not in '., '}
print(my_set_comprehension)
# Out:
# {'Ali', 'Eric', 'John'} {'a', 1, (1, 2)}
# {0, 1, 2, 'Erik', 'a', 'b'}
# {1, 2, 3}
# {0, 1, 2}
# {'y', 'n', 'm', 'a', 'e', 'H', 's', 'i'}

# %% [markdown]
# ##### Sets and lists
# Before we continue, I want to share two commonly used tricks that namy people search for
#
# ###### Deduplicate a list
# sets only contain unique elements, and we can create a set by giving the set() function a list. converting a list to a set is by far to easiest way to do this in python.

# %%
my_list = [1,1,1,1,3,4,5,5,5,5,5,5,5]
my_set = set(my_list)
print(my_set)
# Out:
# {1, 3, 4, 5}

# %% [markdown]
# ###### Convert set to list
# To convert a set to a list, simply create a new list with the set as the argument.

# %%
A = { 1, 2, 3 }
my_list = list(A)
print(my_list)
# Out:
# [1, 2, 3]

# %% [markdown]
# ##### Mathematical Python set operations
# This section will demonstrate and explain all the mathematical set operations.

# %% [markdown]
# ###### Find the difference between Python sets

# %%
A = { 1, 2, 3, 4, 5 }
B = { 3, 4, 5, 6, 7 } 

print(A - B)
print(B - A)
# Out:
# {1, 2}
# {6, 7}

# %% [markdown]
# ###### Find the symmetric difference between Python sets

# %%
A = { 1, 2, 3, 4, 5 }
B = { 3, 4, 5, 6, 7 }

print(A ^ B)
# Out:
# {1, 2, 6, 7}

# %% [markdown]
# ###### Find the intersection of two Python sets

# %%
A = { 1, 2, 3, 4, 5 }
B = { 3, 4, 5, 6, 7 }

print(A & B)
# Out:
# {3, 4, 5}

# %% [markdown]
# ###### Union

# %%
A = { 1, 2, 3 }
B = { 3, 4, 5 }

print(A | B)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ###### Subsets and supersets

# %%
A = { 1, 2, 3 }
B = { 1, 2, 3, 4, 5 }
C = { 1, 2 ,3, 10 }

print(A < B)
print(C < B)
print(B > A)
print(B > C)
print(A < A)
print(A <= A)
print(A >= A)
# Out:
# True
# False
# True
# False
# False
# True
# True

# %% [markdown]
# ##### Other operations on Set
#
# In the next table, I listed some extra operations that you can use to manipulate sets:
#
# |Name	    |Example	        |What is does          |
# |-----------|-------------------|----------------------|
# |add	    |A.add(elem)	    |Add element to set    |
# |remove	    |A.remove(elem) 	|Remove element from set|
# |discard	|A.discard(elem)	|Remove element from the set if it is present (save you a presence check)|
# |pop	    |A.pop()	        |Remove and return an arbitrary element from the set (raises KeyError if the set is empty)|
# |clear	    |A.clear()	        |Remove all elements from the set|

# %% [markdown]
# ### Dictionary
#
# The Python dictionary is one of the language's most powerful data types. In other programming languages and computer science in general, dictionaries are also known as associative arrays. They allow you to associate one or more keys to values.

# %% [markdown]
# ##### Creating a Python Dictionary

# %%
phone_numbers = { 'Jack': '070-02222748', 'Pete': '010-2488634' }
my_empty_dict = { }

print(phone_numbers['Jack'])
# Out:
# 070-02222748

# %% [markdown]
# ##### Access and delete a key-value pair

# %%
phone_numbers = { 'Jack': '070-02222748', 'Pete': '010-2488634' }
phone_numbers['Eric'] = '06-10101010'
del(phone_numbers['Jack'])

print(phone_numbers)

pete = phone_numbers.get('Pete', 80)
print(pete, phone_numbers.get('default'))
# Out:
# {'Pete': '010-2488634', 'Eric': '06-10101010'}
# 010-2488634 None

# %% [markdown]
# ##### More ways to create a Python dictionary
# Depending on your data source, there are more advanced ways to initialize a dictionary that might come in handy.
#
# ###### Using the dict() constructor

# %%
my_dict = dict([ ('Jack', '070-02222748'), ('Pete', '010-2488634'), ('Eric', '06-10101010')])
print(my_dict)
# Out:
# {'Jack': '070-02222748', 'Pete': '010-2488634', 'Eric': '06-10101010'}

# %% [markdown]
# ###### Dictionary Comprehensions

# %%
my_dict = {x: x**2 for x in (2, 4, 6)}
print(my_dict)
# Out:
# {2: 4, 4: 16, 6: 36}

# %% [markdown]
# ###### Using dict.fromkeys

# %%
names = ('Eric', 'Martha', 'Ellen')
phone_numbers = dict.fromkeys(names, None)
print(phone_numbers)
# Out:
# {'Eric': None, 'Martha': None, 'Ellen': None}

# %% [markdown]
# ##### Check if a key exists in a Python dictionary

# %%
phone_numbers = { 'Jack': '070-02222748', 'Pete': '010-2488634' }
print('Jack' in phone_numbers, 'Jack' not in phone_numbers)
# Out:
# True False

# %% [markdown]
# ##### Gettting the length of a Python dictionary

# %%
phone_numbers = {'Jack': '070-02222748',
                 'Pete': '010-2488634',
                 'Eric': '06-10101010'}
print(len(phone_numbers))
# Out:
# 3

# %% [markdown]
# ##### Dictionary view objects
# ###### dict.keys() and dict.values()

# %%
phone_numbers = { 'Jack': '070-02222748',
                  'Pete': '010-2488634',
                  'Eric': '06-10101010'}
names = phone_numbers.keys()
numbers = phone_numbers.values()
phone_numbers['Linda'] = '030-987612312'
print(names)
print(numbers)

for number in numbers:
    print(number)
# Out:
# dict_keys(['Jack', 'Pete', 'Eric', 'Linda'])
# dict_values(['070-02222748', '010-2488634', '06-10101010', '030-987612312'])
# 070-02222748
# 010-2488634
# 06-10101010
# 030-987612312

# %% [markdown]
# ###### dict.items(): loop through a Python dictionary

# %%
phone_numbers = dict([('Jack', '070-02222748'), ('Pete', '010-2488634'), ('Eric', '06-10101010')])
for name, phonenr in phone_numbers.items():
    print(name, phonenr)
# Out:
# Jack 070-02222748
# Pete 010-2488634
# Eric 06-10101010

# %% [markdown]
# ##### More ways to get all the keys

# %%
phone_numbers = {
'Jack': '070-02222748', 
'Pete': '010-2488634', 
'Eric': '06-10101010'
}

print(list(phone_numbers))
print(sorted(phone_numbers))
# Out:
# ['Jack', 'Pete', 'Eric']
# ['Eric', 'Jack', 'Pete']

# %% [markdown]
# ##### Merging dictionaries

# %%
dict1 = { 'a': 1, 'b': 2 }
dict2 = { 'b': 3, 'c': 4 }

merged = dict1 | dict2
merged2 = { **dict1, **dict2 }
print(merged, merged2)
# Out:
# {'a': 1, 'b': 3, 'c': 4} {'a': 1, 'b': 3, 'c': 4}

# %% [markdown]
# ##### Comparing Python dictionaries

# %%
first_dict = { 'a': 1, 'b': 2, 'c': 'a string' }
second_dict = { 'a': 1, 'b': 2, 'c': 'a string'}
print(first_dict == second_dict)
# Out:
# True

# %% [markdown]
# ##### Built-in Python dictionary methods
#
# |Method	                    |What is does	                                                                                        |Example     |
# |---------------------------|-------------------------------------------------------------------------------------------------------|------------|
# |clear()	                |Remove all key/value pairs (empty the dictionary)	                                                    |phone_numbers.clear()|
# |get(key)	                |Get a single item with the given key, with an optional default value	                                |phone_numbers.get('Martha', 'Unknown person')|
# |items()	                |Returns a view object containing key-value pairs from the dictionary	                                |phone_numbers.items()|
# |keys()	                    |Returns a view object with a list of all keys from the dictionary	                                    |phone_numbers.keys()|
# |values()	                |Returns a view_object with a list of all values from the dictionary	                                |phone_numbers.values()|
# |pop(key, default_value)	|Returns and removes the element with the specified key	                                                |phone_numbers.pop('Martha')|
# |popitem()	                |Returns and removes the last inserted item (Python 3.7+) or a random item	                            |phone_numbers.popitem()|
# |setdefault(key, value)	    |Returns the value of the specified key. If the key does not exist, it’s inserted with the given value	|phone_numbers.setdefault('John Doe', 1234)|
# |update(iterable)	        |Add all pairs from given iterable, e.g. a dictionary	                                                |phone_numbers.update({"Alina": 1234, "Alice", 2345})|
